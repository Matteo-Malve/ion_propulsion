# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# Load both CSV files
file_1 = "../results/GO_4_0_12_prove-convergence_data.csv"
file_2 = "../results/GlobRef_4_0_12_prove-convergence_data.csv"

data_1 = pd.read_csv(file_1)
data_2 = pd.read_csv(file_2)

print(data_1)
print(data_2)

# Plot the data
plt.figure(figsize=(10, 8))

# Plot data from first CSV
#plt.loglog(data_1['num_cells'], data_1['errors_sensor_1'], 'k-o', label='Sensor 1 (GO)')
#plt.loglog(data_1['num_cells'], data_1['errors_sensor_2'], 'c-o', label='Sensor 2 (GO)')
#plt.loglog(data_1['num_cells'], data_1['errors_sensor_3'], 'm-o', label='Sensor 3 (GO)')
#plt.loglog(data_1['num_cells'], data_1['errors_sensor_4'], 'b-o', label='Sensor 4 (GO)')
plt.loglog(data_1['num_cells'], data_1['average_errors'], 'y-o', label='Average (GO)')
plt.loglog(data_1['num_cells'], data_1['localized_average_errors'], 'r-o', label='Localized Average (GO)')

# Plot data from second CSV
#plt.loglog(data_2['num_cells'], data_2['errors_sensor_1'], 'k--o', label='Sensor 1 (GlobRef)')
#plt.loglog(data_2['num_cells'], data_2['errors_sensor_2'], 'c--o', label='Sensor 2 (GlobRef)')
#plt.loglog(data_2['num_cells'], data_2['errors_sensor_3'], 'm--o', label='Sensor 3 (GlobRef)')
#plt.loglog(data_2['num_cells'], data_2['errors_sensor_4'], 'b--o', label='Sensor 4 (GlobRef)')
plt.loglog(data_2['num_cells'], data_2['average_errors'], 'y--o', label='Average (GlobRef)')
plt.loglog(data_2['num_cells'], data_2['localized_average_errors'], 'r--o', label='Localized Average (GlobRef)')
plt.loglog(data_2['num_cells'],1/data_2['num_cells']*500000,'b:',label="1/N")
plt.loglog(data_2['num_cells'],1/(data_2['num_cells']**2)*500000,'b:',label="1/N")

# Labeling
plt.xlabel("Number of Cells")
plt.ylabel("Error")
plt.title("Convergence Error Comparison")
plt.legend()
plt.grid(True)

# Show the plot
plt.show()
# Out:
#    num_cells  errors_sensor_1  errors_sensor_2  errors_sensor_3  \
# 0      12492         3.535870          4.17862         0.375710
# 1      14505         0.845059          8.98356         0.344290
# 2      17316         0.097465         10.51360         0.288781
# 3      21123         0.260655         10.44120         0.304779
# 4      26049         0.200295         10.35670         0.295243
# 5      32148         0.137467         10.63650         0.324010
# 6      39978         0.119131         10.54040         0.326265
# 7      49662         0.058340         10.61960         0.307119
# 8      61935         0.102725         10.65260         0.264078
# 9      77847         0.206844         10.72000         0.200737
#
#    errors_sensor_4  average_errors  localized_average_errors
# 0        25.461700        26.59390                 12.555800
# 1        23.534500        22.88480                  5.448360
# 2        20.990700        19.79060                  2.837260
# 3        21.282400        16.65540                  1.763200
# 4        22.962800        13.75150                  1.330450
# 5        25.274400        11.27360                  1.015720
# 6        10.367000         9.19082                  0.791366
# 7        15.147500         7.49621                  0.618372
# 8         0.149295         6.01732                  0.501502
# 9         5.528950         4.77201                  0.335576
#    num_cells  errors_sensor_1  errors_sensor_2  errors_sensor_3  \
# 0      12492         3.535870          4.17862         0.375710
# 1      49968         1.287780          1.42620         0.017479
# 2     199872         0.382579          0.33270         0.003874
#
#    errors_sensor_4  average_errors  localized_average_errors
# 0         25.46170        26.59390                 12.555800
# 1          6.02090         6.34481                  2.901210
# 2          1.40058         1.57407                  0.690944
